# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
import os
from api_keys import api_key
from citipy import citipy
lat_range = (-90, 90)
lng_range = (-180, 180)
#go back and fix output file

# %%
# Starter code
lat_lngs = []
cities = []

lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    if city not in cities:
        cities.append(city)
        
len(cities)
# Out:
# 627

# %%
def Weather_Data(cities, apikey):
    url = "http://api.openweathermap.org/data/2.5/weather"
    payload  = {"appid": api_key,
                "q": cities,
                "units": "imperial"
               }
    r = requests.get(url, params=payload)
    if r.status_code == 200:
        return r.json()
    else:
        return None

# %%
Weather_Data(cities, api_key)
data = []
for city in cities:
    result = Weather_Data(city, api_key)
    if result:
        data.append(result)

# %%
Weather_Frame = pd.DataFrame([{
                "name": d["name"],
                "latitude": d["coord"]["lat"],
                "temp": d["main"]["temp"],
                "humidity (%)": d["main"]["humidity"],
                "cloudiness(%)": d["clouds"]["all"],
                "wind_speed (mph)": d["wind"]["speed"]
    } for d in data])

# %%
Weather_Frame

#change wind speed to mph from m/s
#change temp from K to F
# Out:
#                  name  latitude   temp  humidity (%)  cloudiness(%)  \
# 0        Ponta do Sol    -20.63  67.51            96            100
# 1              Albany     42.65  37.92            81             90
# 2           Sahuaripa     29.05  43.72            61              0
# 3         Verkhoyansk     67.55 -28.52            99              3
# 4            Tamboril     -4.83  76.86            84            100
# ..                ...       ...    ...           ...            ...
# 558         Myaundzha     63.05   5.02            96            100
# 559           Mubende      0.56  63.77            84            100
# 560         La Orilla     18.00  71.33            76            100
# 561          Coquimbo    -29.95  60.80            82             90
# 562  San Juan del Sur     11.25  80.92            80             95
#
#      wind_speed (mph)
# 0                3.76
# 1                1.63
# 2                4.79
# 3                0.54
# 4                5.03
# ..                ...
# 558              2.24
# 559              0.34
# 560              2.04
# 561              4.70
# 562             20.83
#
# [563 rows x 6 columns]
